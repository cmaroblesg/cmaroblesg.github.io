# %% [markdown]
# # Using dataframes
#
# ## Objective:
# - Learn how to use dataframes to open excel files and csv files to process information better and faster.
#
# ## Requirements
# - It's needed to install the following python libraries to work with the dataframes and excel files.
#     * pandas
#     * numpy
#     * openpyxl
#
# **Note:** Open a terminal and instal using the command:
# ```bash
# pip install pandas numpy openpyxl
# ```

# %%
# Needed libraries
import pandas as pd
import functions as func
func.create_NetflixExcelFile()

# %%
# Open excel files
path = './data/Netflix Top 10 Weekly Dataset.xlsx'
excel = pd.ExcelFile(path)

# Check the sheets in the excel file
sheets = excel.sheet_names
print(sheets)
# Out:
# ['all-weeks-global', 'all-weeks-countries', 'most-popular']

# %%
# Get the information from "all-weeks-countries"
df = excel.parse(sheet_name="all-weeks-countries")
df
# Out:
#        country_name country_iso2        week category  weekly_rank  \
# 0         Argentina           AR  2024-06-23    Films            1
# 1         Argentina           AR  2024-06-23    Films            2
# 2         Argentina           AR  2024-06-23    Films            3
# 3         Argentina           AR  2024-06-23    Films            4
# 4         Argentina           AR  2024-06-23    Films            5
# ...             ...          ...         ...      ...          ...
# 290855      Vietnam           VN  2021-07-04       TV            6
# 290856      Vietnam           VN  2021-07-04       TV            7
# 290857      Vietnam           VN  2021-07-04       TV            8
# 290858      Vietnam           VN  2021-07-04       TV            9
# 290859      Vietnam           VN  2021-07-04       TV           10
#
#                                   show_title  \
# 0                            Trigger Warning
# 1                    Cuando acecha la maldad
# ...

# %%
df.loc[(df['country_name'].isin(['Mexico'])) & (df['category'].isin(['Films'])) & (df['week'].isin(['2022-01-16'])), 
       ['country_name', 'week', 'category', 'show_title', 'weekly_rank', 'cumulative_weeks_in_top_10']]
# Out:
# /var/folders/5b/9mpgz_cx3ysbg2l891nwn7640000gn/T/ipykernel_1889/1004127087.py:1: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df.loc[(df['country_name'].isin(['Mexico'])) & (df['category'].isin(['Films'])) & (df['week'].isin(['2022-01-16'])),
#       country_name       week category                             show_title  \
# 30160       Mexico 2022-01-16    Films                                 Brazen
# 30161       Mexico 2022-01-16    Films              The Secret Life of Pets 2
# 30162       Mexico 2022-01-16    Films                         Mother/Android
# 30163       Mexico 2022-01-16    Films                  The Clovehitch Killer
# 30164       Mexico 2022-01-16    Films                          Don't Look Up
# ...

# %%
df = pd.read_csv('./data/all-weeks-countries.tsv', sep='\t')
df.head()
# Out:
#   country_name country_iso2        week category  weekly_rank  \
# 0    Argentina           AR  2024-06-23    Films            1
# 1    Argentina           AR  2024-06-23    Films            2
# 2    Argentina           AR  2024-06-23    Films            3
# 3    Argentina           AR  2024-06-23    Films            4
# 4    Argentina           AR  2024-06-23    Films            5
#
#                              show_title season_title  \
# 0                       Trigger Warning          NaN
# 1               Cuando acecha la maldad          NaN
# 2                           Inheritance          NaN
# 3                           Inheritance          NaN
# 4  Mission: Impossible - Dead Reckoning          NaN
#
#    cumulative_weeks_in_top_10
# 0                           1
# 1                           2
# 2                           1
# 3                           4
# 4                           2
